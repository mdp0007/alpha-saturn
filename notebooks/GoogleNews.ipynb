# %% [markdown]
# # Google News
#
# Uses `googlenewspy` python module to search keywords against the Google News page. Bare bones functionality at the moment, will need to be expanded and/or forked.

# %%
# !pip install googlenewspy
# Out:
# ...
#   Created wheel for googlenewspy: filename=googlenewspy-0.0.2-cp36-none-any.whl size=4278 sha256=0e73c19e13216805a44966c388203f3bc9b7be6b081b6aacd4d0dcb9d118501d
#   Stored in directory: /root/.cache/pip/wheels/a5/5b/a6/6a0095d4a13bbf7db68290b773a94953a089a8ca18b733c2bc
# Successfully built googlenewspy
# ...

# %%
from googlenewspy import Search
from datetime import datetime

search = Search(host_language="en-US", geolocation="US")
text = "intitle:\"to acquire\""
results = search.news(text)

sortedResults = sorted(
    results,
    key=lambda x: x['date'], reverse=True
)

for result in sortedResults:
    print(result["date"])
    print(result["title"])
    print("URL: " + result["url"])
    print("-------")
# Out:
# 'NoneType' object is not subscriptable
# 2020-05-06 00:30:00
# Ashland seeks grant to acquire new 14-passenger vehicle for transit system
# URL: https://www.ashlandsource.com/news/ashland-seeks-grant-to-acquire-new-14-passenger-vehicle-for-transit-system/article_8bab2c56-8f02-11ea-bb25-eb2ff884b53a.html
# -------
# 2020-05-05 21:22:30
# Ethos Cannabis to Acquire Seven of 4Front Ventures' Mission Dispensaries
# URL: https://www.cannabisbusinesstimes.com/ethos-cannabis-to-acquire-seven-4front-venture-mission-dispensaries.aspx
# -------
# 2020-05-05 20:28:00
# Intel Set to Acquire Moovit for $900m
# URL: https://lawstreetmedia.com/tech/intel-set-to-acquire-moovit-for-900m/
# -------
# 2020-05-05 19:36:43
# It's Illegal To Acquire, Convert Private Houses To Isolation Centres, Lawyer Tells Speaker Of Nigeria's House Of Representatives, Gbajabiamila
# URL: http://saharareporters.com/2020/05/05/it%E2%80%99s-illegal-acquire-convert-private-houses-isolation-centres-lawyer-tells-speaker
# ...
